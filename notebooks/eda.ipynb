# %% [markdown]
# # Titanic EDA
#
# Quick exploration of the Kaggle Titanic train.csv.

# %%
import pandas as pd
df = pd.read_csv('../data/train.csv')
print(df.shape)
df.head()

# %%
df.isna().sum()

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].mean()
